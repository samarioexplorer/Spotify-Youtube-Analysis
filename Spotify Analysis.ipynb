# %% [markdown]
# ### SPOTIFY & YOUTUBE ANALYSIS

# %% [markdown]
# ### About Dataset
# Dataset of songs of various artist in the world and for each song is present:
#
# Several statistics of the music version on spotify, including the number of streams;
# Number of views of the official music video of the song on youtube.
#
# ### Content
# It includes 26 variables for each of the songs collected from spotify. These variables are briefly described next:
#
# Track: name of the song, as visible on the Spotify platform.
#
# Artist: name of the artist.
#
# Url_spotify: the Url of the artist.
#
# Album: the album in wich the song is contained on Spotify.
#
# Album_type: indicates if the song is relesead on Spotify as a single or contained in an album.
#
# Uri: a spotify link used to find the song through the API.
#
# Danceability: describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# Energy: is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# Key: the key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#
# Loudness: the overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
# Speechiness: detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# Acousticness: a confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# Instrumentalness: predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# Liveness: detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
# Valence: a measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# Tempo: the overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# Duration_ms: the duration of the track in milliseconds.
#
# Stream: number of streams of the song on Spotify.
#
# Url_youtube: url of the video linked to the song on Youtube, if it have any.
#
# Title: title of the videoclip on youtube.
#
# Channel: name of the channel that have published the video.
#
# Views: number of views.
#
# Likes: number of likes.
#
# Comments: number of comments.
#
# Description: description of the video on Youtube.
#
# Licensed: Indicates whether the video represents licensed content, which means that the content was uploaded to a channel linked to a YouTube content partner and then claimed by that partner.
#
# official_video: boolean value that indicates if the video found is the official video of the song.

# %% [markdown]
# #### Importing the required libraries

# %%
#visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the data
df = pd.read_csv('Spotify_Youtube.csv')
df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  Danceability        Energy           Key      Loudness  \
# count  20718.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean   10358.500000      0.619777      0.635250      5.300348     -7.671680
# std     5980.915774      0.165272      0.214147      3.576449      4.632749
# min        0.000000      0.000000      0.000020      0.000000    -46.251000
# 25%     5179.250000      0.518000      0.507000      2.000000     -8.858000
# 50%    10358.500000      0.637000      0.666000      5.000000     -6.536000
# 75%    15537.750000      0.740250      0.798000      8.000000     -4.931000
# max    20717.000000      0.975000      1.000000     11.000000      0.920000
#
#         Speechiness  Acousticness  Instrumentalness      Liveness  \
# count  20716.000000  20716.000000      20716.000000  20716.000000
# mean       0.096456      0.291535          0.055962      0.193521
# std        0.111960      0.286299          0.193262      0.168531
# ...

# %%
df.info() 
# get the information of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %% [markdown]
# ### Based on the above data the following observation can be made:
#
# 1. This dataset contains 28 columns and 20718 rows.
#
# 2. Some columns contain null values as well further analysis can be performed by examining each column and taking necessary steps to perform the analysis
#
# 3. Additionally insights can be derived by investigating each column, which may provide useful information about Youtube or Spotify data

# %%
df.shape
# Out:
# (20718, 28)

# %% [markdown]
# Here we have 28 columns and 20718 rows in the dataset

# %%
#Viewing the columns
df.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %% [markdown]
# ## Clean data

# %% [markdown]
# #### Remove the unnecessary columns from the dataset

# %%
extra_cols=['Unnamed: 0', 'Title', 'Uri', 'Url_youtube', 'Url_spotify']
df.drop(extra_cols, axis=1, inplace=True)

# %% [markdown]
# Here we have removed 'Unnamed:0', 'Title', 'Uri', 'Url_youtube' columns from the dataset because they are not needed for the analysis

# %%
#Viewing the number of unique values of each column
df.nunique()
# Out:
# Artist               2079
# Track               17841
# Album               11937
# Album_type              3
# Danceability          898
# Energy               1268
# Key                    12
# Loudness             9417
# Speechiness          1303
# Acousticness         3138
# Instrumentalness     4012
# Liveness             1536
# Valence              1293
# Tempo               15024
# Duration_ms         14690
# Channel              6714
# Views               19245
# Likes               17939
# Comments            10485
# Description         17395
# Licensed                2
# official_video          2
# Stream              18461
# dtype: int64

# %% [markdown]
# We can see here that we have the unique values of each column as we have 2079 artists, 17841 tracks, 3 album type, 11937 albums and so on.

# %%
#Checking the number of null values in each column
df.isna().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# official_video      470
# Stream              576
# dtype: int64

# %% [markdown]
# There are more null values in Channel, Views, Licensed, Official Video (470 each), Likes (541), Comments (569), Description (876), Stream (576)

# %%
#Removing all the null values from the columns
df.dropna(inplace=True)

# %%
#Now again rechecking the null values (If there are any)
df.isna().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Description         0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
df.shape #Number of columns and rows
# Out:
# (19170, 23)

# %% [markdown]
# After removing the unnecessary columns and null values from columns, now there are 19170 rows and 23 columns

# %% [markdown]
# #### Changing the data type of the column as per need

# %%
df['Views']=df['Views'].astype('int')
df['Likes']=df['Likes'].astype('int')
df['Comments']=df['Comments'].astype('int')

# %% [markdown]
# Here we have successfully changed the views and comments columns float to int

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#Processing the data
df.head(10)
# Out:
#      Artist                                              Track  \
# 0  Gorillaz                                     Feel Good Inc.
# 1  Gorillaz                                    Rhinestone Eyes
# 2  Gorillaz      New Gold (feat. Tame Impala and Bootie Brown)
# 3  Gorillaz                                 On Melancholy Hill
# 4  Gorillaz                                     Clint Eastwood
# 5  Gorillaz                                               DARE
# 6  Gorillaz  New Gold (feat. Tame Impala and Bootie Brown) ...
# 7  Gorillaz                 She's My Collar (feat. Kali Uchis)
# 8  Gorillaz                  Cracker Island (feat. Thundercat)
# 9  Gorillaz                                        Dirty Harry
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# 1                                      Plastic Beach      album         0.676
# ...

# %% [markdown]
# #### Determining the top 10 artists on the Spotify platform whose songs have more views

# %%
view = df.groupby('Artist')['Views'].agg('sum').reset_index().sort_values('Views', ascending=False).head(10)
view
# Out:
#                        Artist        Views
# 263                Bruno Mars  10231841530
# 1163  Macklemore & Ryan Lewis  10122055560
# 375                  Coldplay   9997277884
# 149                 BLACKPINK   9392961989
# 780                  J Balvin   8464877693
# 1347              Nicki Minaj   8017064073
# 512        Earth, Wind & Fire   6414076580
# 1470              Post Malone   6394420209
# 1390            One Direction   6337601549
# 1349                Nicky Jam   6321868119

# %%
sns.barplot(data=view, x='Artist', y='Views')
plt.title('Top 10 Artist with higher views')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# From the chart above, it can be seen Bruno Mars was the most viewed artist with 10.23 billion views followed by Macklemore & Ryan Lewis and Coldplay with 10.12 billion views and 10 billion views respectively. Blackpink and J Balvin complete the top 5 artists with 9.4 billion and 8.4 billion views. These figures highlight the popularity of these artists and their music, as well as the important role of online video platforms in promoting and distributing music currently.

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:1.0f}'.format(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:1.0f}'.format(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %% [markdown]
# #### Determining the Top 10 artists with most Likes on Youtube

# %%
#groupby the artist
df.groupby('Artist')['Likes'].agg('sum').sort_values(ascending=False).head(10)
# Out:
# Artist
# BTS                139403808
# BLACKPINK          132302505
# Charlie Puth        86336925
# Ed Sheeran          83543319
# Justin Bieber       78579227
# Billie Eilish       73338537
# Imagine Dragons     72274477
# Alan Walker         67977702
# DJ Snake            67775831
# Luis Fonsi          66908489
# Name: Likes, dtype: int32

# %%
#make graph of the top 10 most liked artists in Youtube, bar chart

ax=df.groupby('Artist').agg({'Likes':'sum','Stream':'sum'}).reset_index()
bx=ax.sort_values('Likes', ascending=False).head(10)
sns.barplot(data=bx, x='Likes', y='Artist')
plt.title('Top 10 most Liked Artist')
plt.show()

# %% [markdown]
# It can be seen BTS is the most Liked artist with 14 million likes followed by Blackpink on the second place. Charlie Puth, Ed Sheeran and Justin Bieber complete the TOP 5 of this category with 8.1 million, 8 million and 7.9 million likes respectively.

# %% [markdown]
# ### Determine the Top 10 artist with most streams on Spotify

# %%
df.groupby('Artist')['Stream'].agg('sum').head(10)
# Out:
# Artist
# $NOT                 1.127638e+09
# $uicideboy$          1.745507e+09
# (G)I-DLE             1.304212e+09
# *NSYNC               1.427834e+09
# 070 Shake            4.647486e+08
# 112                  4.989639e+08
# 11:11 Music Group    1.786484e+08
# 1nonly               6.388919e+08
# 2 Chainz             1.995600e+09
# 21 Savage            2.186417e+09
# Name: Stream, dtype: float64

# %%
cx = ax.sort_values('Stream', ascending=False).head(10)

# %%
sns.barplot(data=cx, y='Stream', x='Artist')
plt.xticks(rotation=80)
plt.title('Top 10 most streamed Artist')
plt.show()

# %% [markdown]
# It can be seen from the chart above Post Malone is the most streamed artist with 1.5 billion streams and Ed Sheeran holds the second position with 1.4 billion streams; Dua Lipa, The Weeknd and XXXTentacion occupy the third, fourth and fifth position with 1.3 billion, 1.25 billion and 1.2 billion streams respectively.

# %% [markdown]
# ### Most commented artist on Youtube

# %%
ax = df.groupby('Artist')['Comments'].sum().reset_index().sort_values(by='Comments', ascending=False).head(10)
ax
# Out:
#              Artist  Comments
# 151             BTS  39542659
# 149       BLACKPINK  19605027
# 1722     Stray Kids   8458365
# 1751          TWICE   8384985
# 1410            PSY   7311608
# 908   Justin Bieber   7258967
# 509             EXO   6981950
# 714          Halsey   6981661
# 1390  One Direction   6360892
# 1129     Luis Fonsi   4703428

# %%
sns.barplot(data=ax, y='Artist', x='Comments')
plt.title('Top 10 most commented artist')
plt.show()

# %% [markdown]
# From the table above, the most commented artist is BTS with 39 million comments followed by BLACKPINK with 19 million comments; Stray kids, TWICE and PSY occupy the third, fourth and fifth position with 8.4 million, 8.3 million and 7.3 million comments respectively.

# %% [markdown]
# #### Aggregate views, comments and likes based on artist

# %%
tc=df.groupby('Track').agg({'Views':'sum', 'Comments':'sum', 'Likes':'sum'}).reset_index()
bv=tc.sort_values('Views', ascending=False).head(10)
bv
# Out:
#                                                Track       Views  Comments  \
# 13145     Swalla (feat. Nicki Minaj & Ty Dolla $ign)  5162403752    759525
# 14152                       Thrift Shop (feat. Wanz)  4508467245   1264245
# 12669                       Something Just Like This  4236043204    540890
# 12412                                     Sin Pijama  4172961620    732738
# 12643                   Somebody That I Used To Know  4114890942   1586010
# 2830                                      Con Altura  4093098189    562026
# 1480                                       Bang Bang  4002768766    578607
# 9682                            No Me Conoce - Remix  3958118245    215069
# 13071  Sunflower - Spider-Man: Into the Spider-Verse  3954778068    662127
# 3875         Dusk Till Dawn (feat. Sia) - Radio Edit  3907550097    793267
#
#           Likes
# 13145  28864162
# 14152  30242165
# 12669  20565056
# 12412  17249780
# 12643  29168472
# 2830   18536081
# 1480   22355292
# ...

# %% [markdown]
# #### Top 10 songs on Youtube with higher views.

# %%
sns.barplot(data=bv, y='Track', x='Views')
plt.title('Top 10 most Viewed tracks')
plt.show()

# %% [markdown]
# The most viewed song on Youtube is Swalla feat. Nicky Minaj & Ty Dolla Sign with 5.1 billion views followed by Thrift Shop(Feat. Wanz) with 4.5 billion views.

# %%
av = tc.sort_values('Comments', ascending=False).head(10)
av
# Out:
#                                     Track       Views  Comments      Likes
# 3878                             Dynamite  1841058866  16138145   36609928
# 1981          Boy With Luv (feat. Halsey)  3268219993  13071440   55176413
# 2145                               Butter   850329651   9131761   22723127
# 3435                            Despacito -4294967296   8505582  101577278
# 5032                Gangnam Style (강남스타일) -2147483648   5331537   26399133
# 6029                    How You Like That  1182611467   5130725   24290306
# 1323                                 Baby -2074709656   4817531   23752800
# 12027  See You Again (feat. Charlie Puth) -4294967296   4254691   80295292
# 10695                          Pink Venom   530630417   3637659   14969274
# 10618                 Permission to Dance   563221859   3486944   17090534

# %%
#plt.barh(av['Track'], av['Comments'])
sns.barplot(data=av, y='Track', x='Comments')
plt.title('Top 10 most commented Tracks')
plt.show()
# Out:
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# It can be seen from the chart above that Dynamite is the most commented track on Youtube with over 16 million comments

# %% [markdown]
# #### Most liked song on Youtube or Spotify

# %%
sn=tc.sort_values('Likes', ascending=False).head(10)
sn
# Out:
#                                                 Track       Views  Comments  \
# 3435                                        Despacito -4294967296   8505582
# 12027              See You Again (feat. Charlie Puth) -4294967296   4254691
# 1981                      Boy With Luv (feat. Halsey)  3268219993  13071440
# 16271                            lovely (with Khalid)  3442782701   1123815
# 12151                                        Señorita  2975300305   1280640
# 10060                           Old Town Road - Remix  2406591529    950696
# 13352  Taki Taki (with Selena Gomez, Ozuna & Cardi B) -4294967296   1105938
# 3878                                         Dynamite  1841058866  16138145
# 7698                                          Lean On -4294967296    900340
# 12178                                    Shape of You -2147483648   1130327
#
#            Likes
# 3435   101577278
# 12027   80295292
# 1981    55176413
# 16271   48852042
# 12151   39692236
# 10060   37889373
# ...

# %%
#plt.barh(sn['Track'], sn['Likes'], color='black')
sns.barplot(data=sn, y='Track', x='Likes')
plt.title('Top 10 most Liked Tracks')
plt.show()

# %% [markdown]
# Despacito is the most liked song on Youtube with over 100 million likes

# %% [markdown]
# #### Most viewed song on Youtube and its relationship with streaming on Spotify

# %%
df.groupby('Track').agg({'Views':'sum', 'Stream':'sum'}).reset_index().sort_values(by='Views', ascending=False).head(10)
# Out:
#                                                Track       Views        Stream
# 13145     Swalla (feat. Nicki Minaj & Ty Dolla $ign)  5162403752  3.031746e+09
# 14152                       Thrift Shop (feat. Wanz)  4508467245  2.809622e+09
# 12669                       Something Just Like This  4236043204  4.061651e+09
# 12412                                     Sin Pijama  4172961620  1.420332e+09
# 12643                   Somebody That I Used To Know  4114890942  2.658800e+09
# 2830                                      Con Altura  4093098189  1.360902e+09
# 1480                                       Bang Bang  4002768766  2.360285e+09
# 9682                            No Me Conoce - Remix  3958118245  2.135471e+09
# 13071  Sunflower - Spider-Man: Into the Spider-Verse  3954778068  5.076660e+09
# 3875         Dusk Till Dawn (feat. Sia) - Radio Edit  3907550097  2.756470e+09

# %% [markdown]
# From the table above, it can be seen that the most Viewed song on Youtube is not the most streamed song on Spotify owing to different factors like the way algorithms work, the way songs are promoted, etc.

# %% [markdown]
# #### Which is the most viewed album type on Youtube?

# %%
ac = df.groupby('Album_type')['Views'].sum().head()
ac
# Out:
# Album_type
# album          1148761714701
# compilation      48829222463
# single          330054880076
# Name: Views, dtype: int64

# %%
gp=df.groupby('Album_type')['Views'].sum().reset_index()
sns.set(style="whitegrid")
plt.pie(data=gp, x='Views', labels='Album_type',autopct='%1.0f%%')
plt.title('Album views by Type')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Key Insights
#
# Album is the most popular type with 1.14 trillion views which makes up 75% of the data analysed and it is way higher compared to the other types like compilation and single types.
#
# Single is the second album type with the highest views accounting 330 billion views which is 22% of the data and finally compilation with roughly 48 billion views which is 3% data analysed.

# %% [markdown]
# ### Top 10 licensed album on Youtube & Spotify

# %%
al=df[df['Licensed']==1]
la=al['Album'].value_counts()[:10]
plt.pie(la,autopct='%0.2f%%',labels=la.index)
plt.show()

# %% [markdown]
# From this pie chart above Greatest Hits with 12.99% and Heroes & Villains with 12.34% are the Top 2 licensed albums on Youtube and Spotify

# %% [markdown]
# ### Histogram visualization of the most important factors of singers.

# %%
df.hist(bins=40,figsize=(20,18))
# Out:
# array([[<Axes: title={'center': 'Danceability'}>,
#         <Axes: title={'center': 'Energy'}>,
#         <Axes: title={'center': 'Key'}>,
#         <Axes: title={'center': 'Loudness'}>],
#        [<Axes: title={'center': 'Speechiness'}>,
#         <Axes: title={'center': 'Acousticness'}>,
#         <Axes: title={'center': 'Instrumentalness'}>,
#         <Axes: title={'center': 'Liveness'}>],
#        [<Axes: title={'center': 'Valence'}>,
#         <Axes: title={'center': 'Tempo'}>,
#         <Axes: title={'center': 'Duration_ms'}>,
#         <Axes: title={'center': 'Views'}>],
#        [<Axes: title={'center': 'Likes'}>,
#         <Axes: title={'center': 'Comments'}>,
#         <Axes: title={'center': 'Stream'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ### Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),linewidth=0.6,annot=True,fmt='0.1f', linecolor='black',cmap='jet')
plt.axis('tight')
plt.title('Heatmap')
plt.show()
# Out:
# C:\Users\aniba\AppData\Local\Temp\ipykernel_6356\1268956321.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),linewidth=0.6,annot=True,fmt='0.1f', linecolor='black',cmap='jet')

# %% [markdown]
# According to what is shown on the heatmap, Likes is highly correlated to Comments and Streams which make sense; also Loundness to Energy. Views and stream are moderately correlated as well as Danceability to Valence. On the other side, Loundness to Instrumentalness , Loudness to Acoustiness are not highly correlated.

# %% [markdown]
# ### The most viewed Top 10 albums on Youtube

# %%
A=df.groupby(['Album'])['Views'].sum().reset_index().sort_values(by='Views',ascending=False).head(10)
A
# Out:
#                                             Album        Views
# 9452                                    The Heist  11240587663
# 8970   Swalla (feat. Nicki Minaj & Ty Dolla $ign)   5162403752
# 4296                         Hollywood's Bleeding   5100616676
# 4313                                      Homerun   4795982636
# 10263                                       VIVES   4736798332
# 6038                       Memories...Do Not Open   4635957165
# 9157                                Teenage Dream   4488764640
# 4555                                 Icarus Falls   4202640870
# 3953                                Greatest Hits   4199686140
# 5870                               Making Mirrors   4177867606

# %%
sns.barplot(data=A,x='Views',y='Album')
plt.show()

# %% [markdown]
# ### Which is the most Liked album on Youtube and Spotify?

# %%
b=df.groupby(['Album'])['Likes'].sum().reset_index().sort_values(by='Likes', ascending=False).head(10)
b
# Out:
#                                     Album      Likes
# 10259                                VIDA  123922855
# 8242   See You Again (feat. Charlie Puth)   80295292
# 9452                            The Heist   74964220
# 5755            MAP OF THE SOUL : PERSONA   55176413
# 11164                          ÷ (Deluxe)   53093334
# 11071                lovely (with Khalid)   48852042
# 2589                      Different World   46444440
# 10597      What Is Love? (Deluxe Edition)   43255756
# 237                                  7 EP   39698736
# 8349                Shawn Mendes (Deluxe)   39692236

# %%
sns.barplot(data=b, y='Album', x='Likes')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From above, it can be seen VIDA is the msot liked album with over 120 million likes.

# %% [markdown]
# ### Most commented album on Youtube

# %%
df.groupby(['Album'])['Comments'].sum().reset_index().sort_values(by='Comments', ascending=False).head(10)
# Out:
#                                     Album  Comments
# 997                                    BE  16083138
# 5755            MAP OF THE SOUL : PERSONA  13071440
# 7501                                Proof  12221035
# 10259                                VIDA   9221901
# 1012                            BORN PINK   5400231
# 3725                Gangnam Style (강남스타일)   5331537
# 9011                            THE ALBUM   5130725
# 6398                         My World 2.0   4805805
# 8242   See You Again (feat. Charlie Puth)   4254691
# 7215                  Permission to Dance   3486944

# %%
ax=df.groupby('Album').agg({'Comments':'sum','Stream':'sum'}).reset_index()
bx=ax.sort_values('Comments', ascending=False).head(10)
sns.barplot(data=bx,x='Comments',y='Album')
plt.title('Top 10 most commented albums')
# Out:
# Text(0.5, 1.0, 'Top 10 most commented albums')
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53440 (\N{HANGUL SYLLABLE TA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# BE is the most commented album with 16 milion comments followed by Persona with roughly 13 million comments. A decreasing trend is observed in the chart suggesting the first three albums have more than 10 million views.

# %% [markdown]
# ### TOP Streamed Albums on Youtube

# %%
c=df.groupby(['Album'])['Stream'].sum().reset_index().sort_values(by='Stream', ascending=False).head(10)
c
# Out:
#                                 Album        Stream
# 9452                        The Heist  9.712794e+09
# 4296             Hollywood's Bleeding  9.492893e+09
# 10149                Un Verano Sin Ti  8.463685e+09
# 8039                             SOUR  8.325355e+09
# 3671                 Future Nostalgia  7.379888e+09
# 10597  What Is Love? (Deluxe Edition)  6.874167e+09
# 11164                      ÷ (Deluxe)  6.835601e+09
# 10259                            VIDA  6.634329e+09
# 4915                          Justice  6.537341e+09
# 3277           F*CK LOVE 3+: OVER YOU  6.214954e+09

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:1.0f}'.format(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:1.0f}'.format(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %%
sns.barplot(data=c,x='Stream',y='Album')
plt.title('Top 10 most streamed albums on Youtube')
# Out:
# Text(0.5, 1.0, 'Top 10 most streamed albums on Youtube')

# %% [markdown]
# ### Identifying the TOP 10 channels based on views

# %%
a=df.groupby(['Channel'])['Views'].sum().reset_index().head(10)
b=a.sort_values(by='Views',ascending=False)
b
# Out:
#                                        Channel      Views
# 3  (G)I-DLE (여자)아이들 (Official YouTube Channel)  856952624
# 1                                  $uicideboy$  300806985
# 2                          $uicideboy$ - Topic   35372302
# 9                                 070ShakeVEVO   14117828
# 8                                    070 Shake    2655413
# 7                                        01099    1372441
# 6                             00laurenrebeccah     701798
# 5                               *NSYNC - Topic     206334
# 4                                  * Harbrow *      62108
# 0                                 Khalkho 4119      60765

# %%
sns.barplot(data=b,x='Views',y='Channel')
#plt.barh(b['Channel'],b['Views'])
plt.show()
# Out:
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# G is the most viewed channel on Youtube followed by uicideboy, uicideboy-Topic, 070ShakeVEVO and 070 Shake which complete the TOP 5 channels

# %% [markdown]
# ### What are the TOP liked channels on Youtube?

# %%
a=df.groupby(['Channel'])['Likes'].sum().reset_index().head(10)
b=a.sort_values(by='Likes', ascending=False)
b
# Out:
#                                        Channel     Likes
# 3  (G)I-DLE (여자)아이들 (Official YouTube Channel)  13832196
# 1                                  $uicideboy$   3301561
# 2                          $uicideboy$ - Topic    431852
# 9                                 070ShakeVEVO    400100
# 8                                    070 Shake     96240
# 7                                        01099     31362
# 6                             00laurenrebeccah     10659
# 5                               *NSYNC - Topic      2317
# 4                                  * Harbrow *      1636
# 0                                 Khalkho 4119       589

# %%
sns.barplot(data=b,x='Likes',y='Channel')
# Out:
# <Axes: xlabel='Likes', ylabel='Channel'>
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50668 (\N{HANGUL SYLLABLE YEO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51088 (\N{HANGUL SYLLABLE JA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\aniba\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46308 (\N{HANGUL SYLLABLE DEUL}) missing from current font.
#   func(*args, **kwargs)
# ...

# %% [markdown]
# (G)I-DLE is the most Liked Channel on Youtube. The same trend was observed in the Views chart

# %% [markdown]
# ### Relationship between Energy and Loudness

# %%
sns.lmplot(data=df,x='Energy',y='Loudness',line_kws={'color':'red'})

# %% [markdown]
# The Loundness and Energy showed a positive and exponential correlation where Loudness is defined as the quality of a sound. Once the energy starts increasing the loundness soars which infers that a song with a high energy has a high quality of sound.

# %% [markdown]
# ### Relation between Views and Streams

# %%
sns.lmplot(data=df,x='Views',y='Stream',line_kws={'color':'red'})

# %% [markdown]
# Streams and views are positive correlated as the songs gain views so the streams increase and the songs become more popular over Youtube and Spotify.

# %% [markdown]
# ### Relation between Likes and comments

# %%
sns.lmplot(data=df,x='Likes',y='Comments',line_kws={'color':'red'})

# %% [markdown]
# Comments and Likes are positive correlated as the song get more likes so the comments soars which translates in a more visibility of the song over Youtube and Spotify.

# %% [markdown]
# ### Relation between Likes and views

# %%
df.columns
# Out:
# Index(['Artist', 'Track', 'Album', 'Album_type', 'Danceability', 'Energy',
#        'Key', 'Loudness', 'Speechiness', 'Acousticness', 'Instrumentalness',
#        'Liveness', 'Valence', 'Tempo', 'Duration_ms', 'Channel', 'Views',
#        'Likes', 'Comments', 'Description', 'Licensed', 'official_video',
#        'Stream'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(10,5))
sns.jointplot(data=df,x='Acousticness',y='Energy', kind='hist')
plt.ylabel("Energy", labelpad=20)
plt.xlabel("Acoustiness", labelpad=20)
# Out:
# Text(0.5, 33.249999999999986, 'Acoustiness')

# %% [markdown]
# From above, it can be concluded that A negative correlation between energy and acousticness shows that the higher the track energy, the lower the quantity of acoustic instruments, and vice versa. A similar trend is observed for loudness where acousticness tend to decrease as loudness increase.

# %% [markdown]
# ### Relationship between tempo and speechiness

# %%
fig=plt.figure(figsize=(10,5))
sns.jointplot(data=df,x='Tempo',y='Speechiness', kind='scatter')
plt.ylabel("Speechiness", labelpad=20)
plt.xlabel("Tempo", labelpad=20)
plt.axis('tight')
# Out:
# (-12.168600000000001, 255.5406, -0.0482, 1.0122)

# %% [markdown]
# A huge correlation is observed between speechiness and tempo, as the songs with a faster tempo show a higher level of speechiness

# %% [markdown]
# ### Relationship between tempo and key

# %%
fig=plt.figure(figsize=(10,5))
sns.jointplot(data=df,x='Tempo',y='Key', kind='hist')
plt.ylabel("Key", labelpad=20)
plt.xlabel("Tempo", labelpad=20)
plt.show()

# %% [markdown]
# The key of a song can influence the emotional tone and can also affect its perceived tempo. For example, a song in a minor key might have a slower perceived tempo than a song in a major key, even if the actual tempo is the same.

# %% [markdown]
# ### Relationship between instrumentalness and speechiness

# %%
sns.jointplot(data=df,x='Instrumentalness',y='Speechiness', kind='scatter')
plt.show()

# %% [markdown]
# For the most part, these two variables are often inverse related, as songs with a higher level of speechiness often have a lower level of instrumentalness. The reason being is spoken word or rap tends to be more focused on the lyrics and vocal delivery, while instrumental music is more focused on the music itself.

# %% [markdown]
# ### Relationship between instrumentalness and acousticness

# %%
sns.jointplot(data=df,x='Instrumentalness',y='Acousticness', kind='resid')
plt.show()

# %% [markdown]
# These two variables are generally positive correlated, meaning songs with high level of acousticness also tend to have high level of instrumentalness owing that acoustic instruments are often used to create instrumental music which often features acoustic instruments.

# %% [markdown]
# ### Relationship between Danceability and Energy

# %%
sns.jointplot(data=df,x='Danceability',y='Energy', kind='hex')

# %% [markdown]
# Danceability and Energy are two high correlated variables as songs with high danceability often have a high energy level as well. Danceable songs tipically have a strong and consistent beat that invites the listener to move which generally correlates to a high-energy sound.

# %% [markdown]
# ### Relationship between Loudness and Energy

# %%
sns.jointplot(data=df,x='Loudness',y='Energy', kind='scatter')

# %% [markdown]
# Loudness and energy are two audio features used usually to describe music. Loudness is described as the volume perceived of a song while energy refers to the intensity of a song. For the most part, songs with high loudness tend to have high energy as well, as they are often more intense and dynamic. Nevertheless, there are songs which have high energy without being loud or the other way around.

# %% [markdown]
# ### Relationship between Valence and Energy

# %%
sns.jointplot(data=df,x='Valence',y='Energy', kind='resid')
plt.show()

# %% [markdown]
# A positive correlation is observed between these two features which suggest songs with high energy levels have a more positive emotional tone. The reason being is high-energy songs have a more upbeat and lively sound which is associated with positive emotions like happiness.
